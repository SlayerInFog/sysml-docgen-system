# %% [markdown]
# # SysMLDocGen + OpenMBEE Interface Demo
#
# 这个 notebook 用来演示本系统的接口能力：登录、查看项目/模型/模板/文档、查看 OpenMBEE 适配接口目录，以及上传示例 SysML JSON 模型。
#
# 运行前请确认后端已经启动在 `http://127.0.0.1:8000`。

# %%
from pathlib import Path
import os
import json
import requests
import pandas as pd

BASE_URL = "http://127.0.0.1:8000"
API_URL = f"{BASE_URL}/api"
def find_workspace() -> Path:
    env_workspace = os.environ.get("SYSML_DOCGEN_WORKSPACE")
    if env_workspace:
        return Path(env_workspace).resolve()
    current = Path.cwd().resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "docs" / "sample-sysml-model.json").exists():
            return candidate
    return current

WORKSPACE = find_workspace()
SAMPLE_MODEL = WORKSPACE / "docs" / "sample-sysml-model.json"

USERNAME = "admin"
PASSWORD = "12345"

session = requests.Session()

# %% [markdown]
# ## 1. Health Check

# %%
resp = session.get(f"{BASE_URL}/health")
resp.raise_for_status()
resp.json()
# Out:
# {'status': 'ok', 'app': 'SysMLDocGen'}

# %% [markdown]
# ## 2. Login

# %%
resp = session.post(f"{API_URL}/auth/login", json={"username": USERNAME, "password": PASSWORD})
resp.raise_for_status()
token_payload = resp.json()
session.headers.update({"Authorization": f"Bearer {token_payload['access_token']}"})
token_payload["user"]
# Out:
# {'id': 1,
#  'username': 'admin',
#  'email': '12345@qq.com',
#  'full_name': '12345',
#  'role': 'admin',
#  'is_active': True,
#  'created_at': '2026-05-22T14:20:14'}

# %% [markdown]
# ## 3. Core Data Overview

# %%
def get_json(path, **params):
    response = session.get(f"{API_URL}{path}", params={key: value for key, value in params.items() if value is not None})
    response.raise_for_status()
    return response.json()

projects = get_json("/projects")
models = get_json("/models")
templates = get_json("/documents/templates")
documents = get_json("/documents")

pd.DataFrame([
    {"name": "projects", "count": len(projects)},
    {"name": "models", "count": len(models)},
    {"name": "templates", "count": len(templates)},
    {"name": "documents", "count": len(documents)},
])
# Out:
#         name  count
# 0   projects      1
# 1     models      2
# 2  templates      1
# 3  documents      0

# %%
pd.DataFrame(projects)
# Out:
#    id name code description  owner_id           created_at  \
# 0   2   项目                          1  2026-05-29T16:11:52
#
#             updated_at
# 0  2026-05-29T16:11:52

# %% [markdown]
# ## 4. OpenMBEE Adapter Endpoints

# %%
openmbee_config = get_json("/openmbee/config")
openmbee_config
# Out:
# {'mms_configured': False,
#  'doc_convert_configured': False,
#  'mms_url': None,
#  'doc_convert_url': None}

# %%
openmbee_endpoints = get_json("/openmbee/mms/endpoints")
pd.DataFrame(openmbee_endpoints)
# Out:
#          name method                                               path  \
# 0  mmsVersion    GET                                        /mmsversion
# 1    projects    GET                            /projects?orgId={orgId}
# 2        refs    GET                         /projects/{projectId}/refs
# 3     element    GET  /projects/{projectId}/refs/{refId}/elements/{e...
# 4      search    GET          /projects/{projectId}/refs/{refId}/search
# 5  docConvert   POST                                           /convert
#
#                    description
# 0                     MMS 版本信息
# 1                         项目列表
# 2                      分支/引用列表
# 3                         元素详情
# 4                         元素检索
# 5  HTML/CSS 转 docx、pdf 或 latex

# %% [markdown]
# ## 5. Upload Sample Model

# %%
if not projects:
    response = session.post(f"{API_URL}/projects", json={
        "name": "Jupyter Demo Project",
        "code": "JUPYTER-DEMO",
        "description": "Created from Jupyter notebook",
    })
    response.raise_for_status()
    projects = get_json("/projects")

project_id = projects[0]["id"]
project_id
# Out:
# 2

# %%
with SAMPLE_MODEL.open("rb") as file_obj:
    response = session.post(
        f"{API_URL}/models/upload",
        data={"project_id": str(project_id), "name": "Jupyter Sample Model", "description": "Uploaded from notebook"},
        files={"file": (SAMPLE_MODEL.name, file_obj, "application/json")},
    )
response.raise_for_status()
uploaded_model = response.json()
uploaded_model
# Out:
# {'id': 35,
#  'project_id': 2,
#  'name': 'Jupyter Sample Model',
#  'description': 'Uploaded from notebook',
#  'source_filename': 'sample-sysml-model.json',
#  'version': 1,
#  'branch_name': 'main',
#  'version_tag': None,
#  'status': 'parsed',
#  'uploaded_by': 1,
#  'created_at': '2026-05-30T03:52:42'}

# %% [markdown]
# ## 6. Inspect Model Graph

# %%
graph = get_json(f"/models/{uploaded_model['id']}/graph")
elements_df = pd.DataFrame(graph["elements"])
relations_df = pd.DataFrame(graph["relations"])
elements_df.head(20)
# Out:
#      id  model_id element_uid          name         type  \
# 0  6435        35     REQ-001      自动生成工程文档  Requirement
# 1  6436        35     REQ-002       模型数据可追溯  Requirement
# 2  6437        35     BLK-001        文档生成系统        Block
# 3  6438        35     BLK-002         模型解析器        Block
# 4  6439        35     BLK-003         文档生成器        Block
# 5  6440        35     ACT-001        文档生成流程     Activity
# 6  6441        35     REL-001  生成系统满足自动生成需求      Satisfy
# 7  6442        35     REL-002   文档生成器追踪模型数据        Trace
#
#                      documentation parent_uid
# 0   系统应能够根据 SysML 模型和文档模板自动生成工程文档。        NaN
# 1             生成文档应记录来源模型、模板和生成时间。        NaN
# 2          系统核心块，负责模型管理、模板管理和文档生成。        NaN
# 3  解析 SysML/XMI/JSON 模型文件，抽取元素和关系。    BLK-001
# 4        根据模板渲染 HTML，并导出 DOCX/PDF。    BLK-001
# 5         选择项目、模型和模板后，系统生成文档并保存历史。        NaN
# 6                              NaN        NaN
# 7                              NaN        NaN

# %%
relations_df.head(20)
# Out:
#       id  model_id source_uid target_uid relation_type         label
# 0  12481        35    BLK-001    REQ-001       Satisfy  生成系统满足自动生成需求
# 1  12482        35    BLK-003    REQ-002         Trace   文档生成器追踪模型数据
# 2  12483        35    BLK-001    BLK-002   containment      contains
# 3  12484        35    BLK-001    BLK-003   containment      contains

# %% [markdown]
# ## 7. Generate Document With First Template

# %%
templates = get_json("/documents/templates", project_id=project_id)
if not templates:
    response = session.post(f"{API_URL}/documents/templates/default")
    response.raise_for_status()
    templates = get_json("/documents/templates", project_id=project_id)

template_id = templates[0]["id"]
response = session.post(f"{API_URL}/documents/generate", json={
    "project_id": project_id,
    "model_id": uploaded_model["id"],
    "template_id": template_id,
    "title": "Jupyter Generated SysML Document",
})
response.raise_for_status()
generated_doc = response.json()
generated_doc
# Out:
# {'id': 6,
#  'project_id': 2,
#  'model_id': 35,
#  'template_id': 9,
#  'title': 'Jupyter Generated SysML Document',
#  'status': 'success',
#  'html_content': '<!doctype html>\n<html lang="zh-CN">\n<head>\n  <meta charset="utf-8" />\n  <title>Jupyter Generated SysML Document</title>\n  <style>\n    body { font-family: "Microsoft YaHei", sans-serif; line-height: 1.75; color: #1f2937; }\n    h1, h2, h3 { color: #0f172a; }\n    table { border-collapse: collapse; width: 100%; margin: 16px 0; }\n    th, td { border: 1px solid #cbd5e1; padding: 8px 10px; text-align: left; }\n    th { background: #e2e8f0; }\n    .meta { color: #64748b; }\n  </style>\n</head>\n<body>\n  <h1>Jupyter Generated SysML Document</h1>\n  <p class="meta">模型名称：Jupyter Sample Model ｜ 模型版本：V1</p>\n\n  <h2>1. 模型概述</h2>\n  <p>本文件由 SysML 模型自动生成，覆盖模型元素、结构关系和需求/块/活动等关键内容。</p>\n  <ul>\n    <li>元素总数：8</li>\n    <li>关系总数：4</li>\n    <li>主要元素类型：Block(3)、Requirement(2)、Activity(1)、Satisfy(1)、Trace(1)</li>\n  </ul>\n\n  <h2>2. 模型元素清单</h2>\n  <table>\n    <thead><tr><th>编号</th><th>名称</th><th>类型</th><th>说明</th></tr></thead>\n    <tbody>\n    \n      <tr>\n        <td>1</td>\n        <td>文档生成流程</td>\n        <td>Activity</td>\n        <td>选择项目、模型和模板后，系统生成文档并保存历史。</td>\n      </tr>\n    \n      <tr>\n        <td>2</td>\n        <td>文档生成器</td>\n        <td>Block</td>\n        <td>根据模板渲染 HTML，并导出 DOCX/PDF。</td>\n      </tr>\n    \n      <tr>\n        <td>3</td>\n        <td>文档生成系统</td>\n        <td>Block</td>\n        <td>系统核心块，负责模型管理、模板管理和文档生成。</td>\n      </tr>\n    \n      <tr>\n        <td>4</td>\n        <td>模型解析器</td>\n        <td>Block</td>\n        <td>解析 SysML/XMI/JSON 模型文件，抽取元素和关系。</td>\n      </tr>\n    \n      <tr>\n        <td>5</td>\n        <td>模型数据可追溯</td>\n        <td>Requirement</td>\n        <td>生成文档应记录来源模型、模板和生成时间。</td>\n      </tr>\n    \n      <tr>\n        <td>6</td>\n        <td>自动生成工程文档</td>\n        <td>Requirement</td>\n        <td>系统应能够根据 SysML 模型和文档模板自动生成工程文档。</td>\n      </tr>\n    \n      <tr>\n        <td>7</td>\n        <td>生成系统满足自动生成需求</td>\n        <td>Satisfy</td>\n        <td></td>\n      </tr>\n    \n      <tr>\n        <td>8</td>\n        <td>文档生成器追踪模型数据</td>\n        <td>Trace</td>\n        <td></td>\n      </tr>\n    \n    </tbody>\n  </table>\n\n  <h2>3. 模型关系</h2>\n  <table>\n    <thead><tr><th>源元素</th><th>关系</th><th>目标元素</th></tr></thead>\n    <tbody>\n    \n      <tr>\n        <td>文档生成系统</td>\n        <td>Satisfy</td>\n        <td>自动生成工程文档</td>\n      </tr>\n    \n      <tr>\n        <td>文档生成器</td>\n        <td>Trace</td>\n        <td>模型数据可追溯</td>\n      </tr>\n    \n      <tr>\n        <td>文档生成系统</td>\n        <td>containment</td>\n        <td>模型解析器</td>\n      </tr>\n    \n      <tr>\n        <td>文档生成系统</td>\n        <td>containment</td>\n        <td>文档生成器</td>\n      </tr>\n    \n    </tbody>\n  </table>\n\n  <h2>4. 结论</h2>\n  <p>该文档体现了模型驱动文档生成思路，模型数据作为单一可信源，文档内容可随模型更新重新生成。</p>\n</body>\n</html>',
#  'file_path': 'app\\generated\\document_2_35.html',
#  'created_by': 1,
#  'created_at': '2026-05-30T03:52:47'}
